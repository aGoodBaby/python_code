# %% [markdown]
# # LSTM文本生成实战
# 任务：基于flare文本数据，建立LSTM模型，预测序列文字
# 1、完成数据预处理，将文字序列数据转化为可用于LSTM输入的数据
# 2、查看文字数据预处理后的数据结构，并进行数据分离操作
# 3、针对字符串输入（"flare is a teacher in ai industry.
#    He obtained his phd in Australia."），预测其对应的后续字符
# 备注:模型结构：单层LSTM，输出有20个神经元，每次使用前20个字符预测第21个字符

# %%
#load the data
data = open('flare').read()
#移除换行符
data = data.replace('\n', '').replace('\r', '')
data[:50]
# Out:
# 'flare is a teacher in ai industry. He obtained his'

# %%
#字符去重处理
letters = list(set(data))
num_letters = len(letters)
print(letters, '\n', num_letters)
# Out:
# ['l', 'f', 'H', 'i', 't', 'c', 's', 'A', 'u', 'e', 'r', 'a', 'n', 'p', 'y', 'b', 'o', 'S', 'm', ' ', 'd', '.', 'h']
#  23

# %%
#建立字典
#int to char
int_to_char = {a: b for a, b in enumerate(letters)}
#char to int
char_to_int = {b: a for a, b in enumerate(letters)}
print(int_to_char, '\n', char_to_int)
# Out:
# {0: 'l', 1: 'f', 2: 'H', 3: 'i', 4: 't', 5: 'c', 6: 's', 7: 'A', 8: 'u', 9: 'e', 10: 'r', 11: 'a', 12: 'n', 13: 'p', 14: 'y', 15: 'b', 16: 'o', 17: 'S', 18: 'm', 19: ' ', 20: 'd', 21: '.', 22: 'h'}
#  {'l': 0, 'f': 1, 'H': 2, 'i': 3, 't': 4, 'c': 5, 's': 6, 'A': 7, 'u': 8, 'e': 9, 'r': 10, 'a': 11, 'n': 12, 'p': 13, 'y': 14, 'b': 15, 'o': 16, 'S': 17, 'm': 18, ' ': 19, 'd': 20, '.': 21, 'h': 22}

# %%
import numpy as np
from keras.utils import to_categorical


#滑动窗口提取数据
def extract_data(data, slide):
    x = []
    y = []
    for i in range(len(data) - slide):
        x.append([a for a in data[i:i + slide]])
        y.append(data[i + slide])
    return x, y


#字符到数字的批量转化
def char_to_int_Data(x, y, char_to_int):
    x_to_int = []
    y_to_int = []
    for i in range(len(x)):
        x_to_int.append([char_to_int[char] for char in x[i]])
        y_to_int.append([char_to_int[char] for char in y[i]])
    return x_to_int, y_to_int


#实现输入字符文章的批量处理，输入整个字符，滑动窗口大小，转化字典
def data_preprocessing(data, slide, num_letters, char_to_int):
    char_Data = extract_data(data, slide)
    int_Data = char_to_int_Data(char_Data[0], char_Data[1], char_to_int)
    Input = int_Data[0]
    Output = list(np.array(int_Data[1]).flatten())
    Input_RESHAPED = np.array(Input).reshape(len(Input), slide)
    new = np.random.randint(
        0,
        10,
        size=[Input_RESHAPED.shape[0], Input_RESHAPED.shape[1], num_letters])
    for i in range(Input_RESHAPED.shape[0]):
        for j in range(Input_RESHAPED.shape[1]):
            new[i, j, :] = to_categorical(Input_RESHAPED[i, j],
                                          num_classes=num_letters)
    return new, Output

# %%
#extract X and y from text data
time_step = 20
X, y = data_preprocessing(data, time_step, num_letters, char_to_int)

# %%
#split the data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.1,
                                                    random_state=10)
y_train_category = to_categorical(y_train, num_letters)

# %%
#set up the model
from keras.models import Sequential
from keras.layers import Dense, LSTM
model = Sequential()
model.add(
    LSTM(units=20,
         input_shape=(X_train.shape[1], X_train.shape[2]),
         activation='relu'))
model.add(Dense(units=num_letters, activation='softmax'))
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 20)                3520
# _________________________________________________________________
# dense_1 (Dense)              (None, 23)                483
# =================================================================
# Total params: 4,003
# Trainable params: 4,003
# Non-trainable params: 0
# _________________________________________________________________

# %%
#train the model
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'
model.fit(X_train, y_train_category, batch_size=1000, epochs=5)
# Out:
# Epoch 1/5
# 50533/50533 [==============================] - 10s 193us/step - loss: 0.1902 - accuracy: 0.9669
# Epoch 2/5
# 50533/50533 [==============================] - 10s 206us/step - loss: 0.1285 - accuracy: 0.9838
# Epoch 3/5
# 50533/50533 [==============================] - 10s 197us/step - loss: 0.4397 - accuracy: 0.9021
# Epoch 4/5
# 50533/50533 [==============================] - 10s 200us/step - loss: 1.1072 - accuracy: 0.6550
# Epoch 5/5
# 50533/50533 [==============================] - 10s 194us/step - loss: 0.1353 - accuracy: 0.9764

# %%
#make prediction based on the training data
y_train_predict = model.predict_classes(X_train)
y_train_predict_char = [int_to_char[i] for i in y_train_predict]
from sklearn.metrics import accuracy_score
accuracy_train = accuracy_score(y_train, y_train_predict)
accuracy_train
# Out:
# 0.9914907090416164

# %%
y_test_predict = model.predict_classes(X_test)
accuracy_test = accuracy_score(y_text, y_test_predict)
accuracy_test
# Out:
# 0.992520035618878

# %%
new_letters = 'flare is a teacher in ai industry. He obtained his phd in Australia. Australia is a country in the Southern Hemisphere.flare is a teacher in ai industry. He obtained his phd in Australia. Australia is a country in the Southern Hemisphere.flare is a teacher in ai industry. He obtained his phd in Australia. Australia is a country in the Southern Hemisphere.flare is a teacher in ai industry. He obtained his phd in Australia. Australia is a country in the Southern Hemisphere.'
X_new, y_new = data_preprocessing(new_letters, time_step, num_letters,
                                  char_to_int)
y_new_predict = model.predict_classes(X_new)
y_new_predict_char = [int_to_char[i] for i in y_new_predict]
for i in range(0, X_new.shape[0]):
    print(new_letters[i:i + 20], '--predict next letter is--',
          y_new_predict_char[i])
# Out:
# flare is a teacher i --predict next letter is-- n
# lare is a teacher in --predict next letter is--
# are is a teacher in  --predict next letter is-- a
# re is a teacher in a --predict next letter is-- i
# e is a teacher in ai --predict next letter is-- n
#  is a teacher in ai  --predict next letter is-- i
# is a teacher in ai i --predict next letter is-- n
# s a teacher in ai in --predict next letter is-- d
#  a teacher in ai ind --predict next letter is-- u
# a teacher in ai indu --predict next letter is-- s
#  teacher in ai indus --predict next letter is-- t
# teacher in ai indust --predict next letter is-- r
# eacher in ai industr --predict next letter is-- y
# acher in ai industry --predict next letter is-- .
# cher in ai industry. --predict next letter is--
# her in ai industry.  --predict next letter is-- H
# er in ai industry. H --predict next letter is-- e
# r in ai industry. He --predict next letter is--
#  in ai industry. He  --predict next letter is-- o
# in ai industry. He o --predict next letter is-- b
# n ai industry. He ob --predict next letter is-- t
#  ai industry. He obt --predict next letter is-- a
# ai industry. He obta --predict next letter is-- i
# i industry. He obtai --predict next letter is-- n
#  industry. He obtain --predict next letter is-- e
# industry. He obtaine --predict next letter is-- d
# ndustry. He obtained --predict next letter is--
# dustry. He obtained  --predict next letter is-- h
# ustry. He obtained h --predict next letter is-- i
# stry. He obtained hi --predict next letter is-- s
# try. He obtained his --predict next letter is--
# ry. He obtained his  --predict next letter is-- p
# y. He obtained his p --predict next letter is-- h
# . He obtained his ph --predict next letter is-- d
#  He obtained his phd --predict next letter is--
# He obtained his phd  --predict next letter is-- i
# e obtained his phd i --predict next letter is-- n
#  obtained his phd in --predict next letter is--
# obtained his phd in  --predict next letter is-- A
# btained his phd in A --predict next letter is-- u
# tained his phd in Au --predict next letter is-- s
# ained his phd in Aus --predict next letter is-- t
# ined his phd in Aust --predict next letter is-- r
# ned his phd in Austr --predict next letter is-- a
# ed his phd in Austra --predict next letter is-- l
# d his phd in Austral --predict next letter is-- i
#  his phd in Australi --predict next letter is-- a
# his phd in Australia --predict next letter is-- .
# is phd in Australia. --predict next letter is--
# s phd in Australia.  --predict next letter is-- A
#  phd in Australia. A --predict next letter is-- u
# phd in Australia. Au --predict next letter is-- s
# hd in Australia. Aus --predict next letter is-- t
# d in Australia. Aust --predict next letter is-- r
#  in Australia. Austr --predict next letter is-- a
# in Australia. Austra --predict next letter is-- l
# n Australia. Austral --predict next letter is-- i
#  Australia. Australi --predict next letter is-- a
# Australia. Australia --predict next letter is--
# ustralia. Australia  --predict next letter is-- i
# stralia. Australia i --predict next letter is-- s
# tralia. Australia is --predict next letter is--
# ralia. Australia is  --predict next letter is-- a
# alia. Australia is a --predict next letter is--
# lia. Australia is a  --predict next letter is-- c
# ia. Australia is a c --predict next letter is-- o
# a. Australia is a co --predict next letter is-- u
# . Australia is a cou --predict next letter is-- n
#  Australia is a coun --predict next letter is-- t
# Australia is a count --predict next letter is-- r
# ustralia is a countr --predict next letter is-- y
# stralia is a country --predict next letter is--
# tralia is a country  --predict next letter is-- i
# ralia is a country i --predict next letter is-- n
# alia is a country in --predict next letter is--
# lia is a country in  --predict next letter is-- t
# ia is a country in t --predict next letter is-- h
# a is a country in th --predict next letter is-- e
#  is a country in the --predict next letter is--
# is a country in the  --predict next letter is-- S
# s a country in the S --predict next letter is-- o
#  a country in the So --predict next letter is-- u
# a country in the Sou --predict next letter is-- t
#  country in the Sout --predict next letter is-- h
# country in the South --predict next letter is-- e
# ountry in the Southe --predict next letter is-- r
# untry in the Souther --predict next letter is-- n
# ntry in the Southern --predict next letter is--
# try in the Southern  --predict next letter is-- H
# ry in the Southern H --predict next letter is-- e
# y in the Southern He --predict next letter is-- m
#  in the Southern Hem --predict next letter is-- i
# in the Southern Hemi --predict next letter is-- s
# n the Southern Hemis --predict next letter is-- p
#  the Southern Hemisp --predict next letter is-- h
# the Southern Hemisph --predict next letter is-- e
# he Southern Hemisphe --predict next letter is-- r
# e Southern Hemispher --predict next letter is-- e
#  Southern Hemisphere --predict next letter is-- .
# Southern Hemisphere. --predict next letter is-- f
# outhern Hemisphere.f --predict next letter is-- l
# uthern Hemisphere.fl --predict next letter is-- a
# thern Hemisphere.fla --predict next letter is-- r
# hern Hemisphere.flar --predict next letter is-- e
# ern Hemisphere.flare --predict next letter is--
# rn Hemisphere.flare  --predict next letter is-- i
# n Hemisphere.flare i --predict next letter is-- s
#  Hemisphere.flare is --predict next letter is--
# Hemisphere.flare is  --predict next letter is-- a
# emisphere.flare is a --predict next letter is--
# misphere.flare is a  --predict next letter is-- t
# isphere.flare is a t --predict next letter is-- e
# sphere.flare is a te --predict next letter is-- a
# phere.flare is a tea --predict next letter is-- c
# here.flare is a teac --predict next letter is-- h
# ere.flare is a teach --predict next letter is-- e
# re.flare is a teache --predict next letter is-- r
# e.flare is a teacher --predict next letter is--
# .flare is a teacher  --predict next letter is-- i
# flare is a teacher i --predict next letter is-- n
# lare is a teacher in --predict next letter is--
# are is a teacher in  --predict next letter is-- a
# re is a teacher in a --predict next letter is-- i
# e is a teacher in ai --predict next letter is-- n
#  is a teacher in ai  --predict next letter is-- i
# is a teacher in ai i --predict next letter is-- n
# s a teacher in ai in --predict next letter is-- d
#  a teacher in ai ind --predict next letter is-- u
# a teacher in ai indu --predict next letter is-- s
#  teacher in ai indus --predict next letter is-- t
# teacher in ai indust --predict next letter is-- r
# eacher in ai industr --predict next letter is-- y
# acher in ai industry --predict next letter is-- .
# cher in ai industry. --predict next letter is--
# her in ai industry.  --predict next letter is-- H
# er in ai industry. H --predict next letter is-- e
# r in ai industry. He --predict next letter is--
#  in ai industry. He  --predict next letter is-- o
# in ai industry. He o --predict next letter is-- b
# n ai industry. He ob --predict next letter is-- t
#  ai industry. He obt --predict next letter is-- a
# ai industry. He obta --predict next letter is-- i
# i industry. He obtai --predict next letter is-- n
#  industry. He obtain --predict next letter is-- e
# industry. He obtaine --predict next letter is-- d
# ndustry. He obtained --predict next letter is--
# dustry. He obtained  --predict next letter is-- h
# ustry. He obtained h --predict next letter is-- i
# stry. He obtained hi --predict next letter is-- s
# try. He obtained his --predict next letter is--
# ry. He obtained his  --predict next letter is-- p
# y. He obtained his p --predict next letter is-- h
# . He obtained his ph --predict next letter is-- d
#  He obtained his phd --predict next letter is--
# He obtained his phd  --predict next letter is-- i
# e obtained his phd i --predict next letter is-- n
#  obtained his phd in --predict next letter is--
# obtained his phd in  --predict next letter is-- A
# btained his phd in A --predict next letter is-- u
# tained his phd in Au --predict next letter is-- s
# ained his phd in Aus --predict next letter is-- t
# ined his phd in Aust --predict next letter is-- r
# ned his phd in Austr --predict next letter is-- a
# ed his phd in Austra --predict next letter is-- l
# d his phd in Austral --predict next letter is-- i
#  his phd in Australi --predict next letter is-- a
# his phd in Australia --predict next letter is-- .
# is phd in Australia. --predict next letter is--
# s phd in Australia.  --predict next letter is-- A
#  phd in Australia. A --predict next letter is-- u
# phd in Australia. Au --predict next letter is-- s
# hd in Australia. Aus --predict next letter is-- t
# d in Australia. Aust --predict next letter is-- r
#  in Australia. Austr --predict next letter is-- a
# in Australia. Austra --predict next letter is-- l
# n Australia. Austral --predict next letter is-- i
#  Australia. Australi --predict next letter is-- a
# Australia. Australia --predict next letter is--
# ustralia. Australia  --predict next letter is-- i
# stralia. Australia i --predict next letter is-- s
# tralia. Australia is --predict next letter is--
# ralia. Australia is  --predict next letter is-- a
# alia. Australia is a --predict next letter is--
# lia. Australia is a  --predict next letter is-- c
# ia. Australia is a c --predict next letter is-- o
# a. Australia is a co --predict next letter is-- u
# . Australia is a cou --predict next letter is-- n
#  Australia is a coun --predict next letter is-- t
# Australia is a count --predict next letter is-- r
# ustralia is a countr --predict next letter is-- y
# stralia is a country --predict next letter is--
# tralia is a country  --predict next letter is-- i
# ralia is a country i --predict next letter is-- n
# alia is a country in --predict next letter is--
# lia is a country in  --predict next letter is-- t
# ia is a country in t --predict next letter is-- h
# a is a country in th --predict next letter is-- e
#  is a country in the --predict next letter is--
# is a country in the  --predict next letter is-- S
# s a country in the S --predict next letter is-- o
#  a country in the So --predict next letter is-- u
# a country in the Sou --predict next letter is-- t
#  country in the Sout --predict next letter is-- h
# country in the South --predict next letter is-- e
# ountry in the Southe --predict next letter is-- r
# untry in the Souther --predict next letter is-- n
# ntry in the Southern --predict next letter is--
# try in the Southern  --predict next letter is-- H
# ry in the Southern H --predict next letter is-- e
# y in the Southern He --predict next letter is-- m
#  in the Southern Hem --predict next letter is-- i
# in the Southern Hemi --predict next letter is-- s
# n the Southern Hemis --predict next letter is-- p
#  the Southern Hemisp --predict next letter is-- h
# the Southern Hemisph --predict next letter is-- e
# he Southern Hemisphe --predict next letter is-- r
# e Southern Hemispher --predict next letter is-- e
#  Southern Hemisphere --predict next letter is-- .
# Southern Hemisphere. --predict next letter is-- f
# outhern Hemisphere.f --predict next letter is-- l
# uthern Hemisphere.fl --predict next letter is-- a
# thern Hemisphere.fla --predict next letter is-- r
# hern Hemisphere.flar --predict next letter is-- e
# ern Hemisphere.flare --predict next letter is--
# rn Hemisphere.flare  --predict next letter is-- i
# n Hemisphere.flare i --predict next letter is-- s
#  Hemisphere.flare is --predict next letter is--
# Hemisphere.flare is  --predict next letter is-- a
# emisphere.flare is a --predict next letter is--
# misphere.flare is a  --predict next letter is-- t
# isphere.flare is a t --predict next letter is-- e
# sphere.flare is a te --predict next letter is-- a
# phere.flare is a tea --predict next letter is-- c
# here.flare is a teac --predict next letter is-- h
# ere.flare is a teach --predict next letter is-- e
# re.flare is a teache --predict next letter is-- r
# e.flare is a teacher --predict next letter is--
# .flare is a teacher  --predict next letter is-- i
# flare is a teacher i --predict next letter is-- n
# lare is a teacher in --predict next letter is--
# are is a teacher in  --predict next letter is-- a
# re is a teacher in a --predict next letter is-- i
# e is a teacher in ai --predict next letter is-- n
#  is a teacher in ai  --predict next letter is-- i
# is a teacher in ai i --predict next letter is-- n
# s a teacher in ai in --predict next letter is-- d
#  a teacher in ai ind --predict next letter is-- u
# a teacher in ai indu --predict next letter is-- s
#  teacher in ai indus --predict next letter is-- t
# teacher in ai indust --predict next letter is-- r
# eacher in ai industr --predict next letter is-- y
# acher in ai industry --predict next letter is-- .
# cher in ai industry. --predict next letter is--
# her in ai industry.  --predict next letter is-- H
# er in ai industry. H --predict next letter is-- e
# r in ai industry. He --predict next letter is--
#  in ai industry. He  --predict next letter is-- o
# in ai industry. He o --predict next letter is-- b
# n ai industry. He ob --predict next letter is-- t
#  ai industry. He obt --predict next letter is-- a
# ai industry. He obta --predict next letter is-- i
# i industry. He obtai --predict next letter is-- n
#  industry. He obtain --predict next letter is-- e
# industry. He obtaine --predict next letter is-- d
# ndustry. He obtained --predict next letter is--
# dustry. He obtained  --predict next letter is-- h
# ustry. He obtained h --predict next letter is-- i
# stry. He obtained hi --predict next letter is-- s
# try. He obtained his --predict next letter is--
# ry. He obtained his  --predict next letter is-- p
# y. He obtained his p --predict next letter is-- h
# . He obtained his ph --predict next letter is-- d
#  He obtained his phd --predict next letter is--
# He obtained his phd  --predict next letter is-- i
# e obtained his phd i --predict next letter is-- n
#  obtained his phd in --predict next letter is--
# obtained his phd in  --predict next letter is-- A
# btained his phd in A --predict next letter is-- u
# tained his phd in Au --predict next letter is-- s
# ained his phd in Aus --predict next letter is-- t
# ined his phd in Aust --predict next letter is-- r
# ned his phd in Austr --predict next letter is-- a
# ed his phd in Austra --predict next letter is-- l
# d his phd in Austral --predict next letter is-- i
#  his phd in Australi --predict next letter is-- a
# his phd in Australia --predict next letter is-- .
# is phd in Australia. --predict next letter is--
# s phd in Australia.  --predict next letter is-- A
#  phd in Australia. A --predict next letter is-- u
# phd in Australia. Au --predict next letter is-- s
# hd in Australia. Aus --predict next letter is-- t
# d in Australia. Aust --predict next letter is-- r
#  in Australia. Austr --predict next letter is-- a
# in Australia. Austra --predict next letter is-- l
# n Australia. Austral --predict next letter is-- i
#  Australia. Australi --predict next letter is-- a
# Australia. Australia --predict next letter is--
# ustralia. Australia  --predict next letter is-- i
# stralia. Australia i --predict next letter is-- s
# tralia. Australia is --predict next letter is--
# ralia. Australia is  --predict next letter is-- a
# alia. Australia is a --predict next letter is--
# lia. Australia is a  --predict next letter is-- c
# ia. Australia is a c --predict next letter is-- o
# a. Australia is a co --predict next letter is-- u
# . Australia is a cou --predict next letter is-- n
#  Australia is a coun --predict next letter is-- t
# Australia is a count --predict next letter is-- r
# ustralia is a countr --predict next letter is-- y
# stralia is a country --predict next letter is--
# tralia is a country  --predict next letter is-- i
# ralia is a country i --predict next letter is-- n
# alia is a country in --predict next letter is--
# lia is a country in  --predict next letter is-- t
# ia is a country in t --predict next letter is-- h
# a is a country in th --predict next letter is-- e
#  is a country in the --predict next letter is--
# is a country in the  --predict next letter is-- S
# s a country in the S --predict next letter is-- o
#  a country in the So --predict next letter is-- u
# a country in the Sou --predict next letter is-- t
#  country in the Sout --predict next letter is-- h
# country in the South --predict next letter is-- e
# ountry in the Southe --predict next letter is-- r
# untry in the Souther --predict next letter is-- n
# ntry in the Southern --predict next letter is--
# try in the Southern  --predict next letter is-- H
# ry in the Southern H --predict next letter is-- e
# y in the Southern He --predict next letter is-- m
#  in the Southern Hem --predict next letter is-- i
# in the Southern Hemi --predict next letter is-- s
# n the Southern Hemis --predict next letter is-- p
#  the Southern Hemisp --predict next letter is-- h
# the Southern Hemisph --predict next letter is-- e
# he Southern Hemisphe --predict next letter is-- r
# e Southern Hemispher --predict next letter is-- e
#  Southern Hemisphere --predict next letter is-- .
# Southern Hemisphere. --predict next letter is-- f
# outhern Hemisphere.f --predict next letter is-- l
# uthern Hemisphere.fl --predict next letter is-- a
# thern Hemisphere.fla --predict next letter is-- r
# hern Hemisphere.flar --predict next letter is-- e
# ern Hemisphere.flare --predict next letter is--
# rn Hemisphere.flare  --predict next letter is-- i
# n Hemisphere.flare i --predict next letter is-- s
#  Hemisphere.flare is --predict next letter is--
# Hemisphere.flare is  --predict next letter is-- a
# emisphere.flare is a --predict next letter is--
# misphere.flare is a  --predict next letter is-- t
# isphere.flare is a t --predict next letter is-- e
# sphere.flare is a te --predict next letter is-- a
# phere.flare is a tea --predict next letter is-- c
# here.flare is a teac --predict next letter is-- h
# ere.flare is a teach --predict next letter is-- e
# re.flare is a teache --predict next letter is-- r
# e.flare is a teacher --predict next letter is--
# .flare is a teacher  --predict next letter is-- i
# flare is a teacher i --predict next letter is-- n
# lare is a teacher in --predict next letter is--
# are is a teacher in  --predict next letter is-- a
# re is a teacher in a --predict next letter is-- i
# e is a teacher in ai --predict next letter is-- n
#  is a teacher in ai  --predict next letter is-- i
# is a teacher in ai i --predict next letter is-- n
# s a teacher in ai in --predict next letter is-- d
#  a teacher in ai ind --predict next letter is-- u
# a teacher in ai indu --predict next letter is-- s
#  teacher in ai indus --predict next letter is-- t
# teacher in ai indust --predict next letter is-- r
# eacher in ai industr --predict next letter is-- y
# acher in ai industry --predict next letter is-- .
# cher in ai industry. --predict next letter is--
# her in ai industry.  --predict next letter is-- H
# er in ai industry. H --predict next letter is-- e
# r in ai industry. He --predict next letter is--
#  in ai industry. He  --predict next letter is-- o
# in ai industry. He o --predict next letter is-- b
# n ai industry. He ob --predict next letter is-- t
#  ai industry. He obt --predict next letter is-- a
# ai industry. He obta --predict next letter is-- i
# i industry. He obtai --predict next letter is-- n
#  industry. He obtain --predict next letter is-- e
# industry. He obtaine --predict next letter is-- d
# ndustry. He obtained --predict next letter is--
# dustry. He obtained  --predict next letter is-- h
# ustry. He obtained h --predict next letter is-- i
# stry. He obtained hi --predict next letter is-- s
# try. He obtained his --predict next letter is--
# ry. He obtained his  --predict next letter is-- p
# y. He obtained his p --predict next letter is-- h
# . He obtained his ph --predict next letter is-- d
#  He obtained his phd --predict next letter is--
# He obtained his phd  --predict next letter is-- i
# e obtained his phd i --predict next letter is-- n
#  obtained his phd in --predict next letter is--
# obtained his phd in  --predict next letter is-- A
# btained his phd in A --predict next letter is-- u
# tained his phd in Au --predict next letter is-- s
# ained his phd in Aus --predict next letter is-- t
# ined his phd in Aust --predict next letter is-- r
# ned his phd in Austr --predict next letter is-- a
# ed his phd in Austra --predict next letter is-- l
# d his phd in Austral --predict next letter is-- i
#  his phd in Australi --predict next letter is-- a
# his phd in Australia --predict next letter is-- .
# is phd in Australia. --predict next letter is--
# s phd in Australia.  --predict next letter is-- A
#  phd in Australia. A --predict next letter is-- u
# phd in Australia. Au --predict next letter is-- s
# hd in Australia. Aus --predict next letter is-- t
# d in Australia. Aust --predict next letter is-- r
#  in Australia. Austr --predict next letter is-- a
# in Australia. Austra --predict next letter is-- l
# n Australia. Austral --predict next letter is-- i
#  Australia. Australi --predict next letter is-- a
# Australia. Australia --predict next letter is--
# ustralia. Australia  --predict next letter is-- i
# stralia. Australia i --predict next letter is-- s
# tralia. Australia is --predict next letter is--
# ralia. Australia is  --predict next letter is-- a
# alia. Australia is a --predict next letter is--
# lia. Australia is a  --predict next letter is-- c
# ia. Australia is a c --predict next letter is-- o
# a. Australia is a co --predict next letter is-- u
# . Australia is a cou --predict next letter is-- n
#  Australia is a coun --predict next letter is-- t
# Australia is a count --predict next letter is-- r
# ustralia is a countr --predict next letter is-- y
# stralia is a country --predict next letter is--
# tralia is a country  --predict next letter is-- i
# ralia is a country i --predict next letter is-- n
# alia is a country in --predict next letter is--
# lia is a country in  --predict next letter is-- t
# ia is a country in t --predict next letter is-- h
# a is a country in th --predict next letter is-- e
#  is a country in the --predict next letter is--
# is a country in the  --predict next letter is-- S
# s a country in the S --predict next letter is-- o
#  a country in the So --predict next letter is-- u
# a country in the Sou --predict next letter is-- t
#  country in the Sout --predict next letter is-- h
# country in the South --predict next letter is-- e
# ountry in the Southe --predict next letter is-- r
# untry in the Souther --predict next letter is-- n
# ntry in the Southern --predict next letter is--
# try in the Southern  --predict next letter is-- H
# ry in the Southern H --predict next letter is-- e
# y in the Southern He --predict next letter is-- m
#  in the Southern Hem --predict next letter is-- i
# in the Southern Hemi --predict next letter is-- s
# n the Southern Hemis --predict next letter is-- p
#  the Southern Hemisp --predict next letter is-- h
# the Southern Hemisph --predict next letter is-- e
# he Southern Hemisphe --predict next letter is-- r
# e Southern Hemispher --predict next letter is-- e
#  Southern Hemisphere --predict next letter is-- .

# %% [markdown]
# LSTM文本生成实战summary：
# 1、通过搭建LSTM模型，实现了基于文本序列的字符生成功能
# 2、学习了文本加载，字典生成方法
# 3、掌握了文本的数据预处理方法，并熟悉了转化数据的结构
# 4、实现了对新文本数据的字符预测
